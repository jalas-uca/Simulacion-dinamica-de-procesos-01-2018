% %% [markdown]
% # Modelo 1.
%
% El modelo consistía de una única ecuación:
%
% $$
% \frac{dh}{dt}=3-0.5h
% $$
%
% Resolución en Octave:

% %%
t=0:0.5:20;

function dhdt=dhdt(h)
    dhdt=3-0.5*h;
endfunction

h=lsode("dhdt",1.5,t);

plot(t,h)
